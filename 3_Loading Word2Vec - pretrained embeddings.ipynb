# %% [markdown]
# # Loading Google’s Word2Vec Embedding
#
# A pre-trained model is nothing more than a file containing tokens and their associated word vectors.
# The pre-trained Google word2vec model was trained on Google news data (about 100 billion words);
# it contains 3 million words and phrases and was fit using 300-dimensional word vectors.

# %%
# Snippet to download the word2Vec model:
# !wget -P /root/input/ -c "https://s3.amazonaws.com/dl4j-distribution/GoogleNews-vectors-negative300.bin.gz"

EMBEDDING_FILE = '/root/input/GoogleNews-vectors-negative300.bin.gz'

# %%
from gensim.models import KeyedVectors

model = KeyedVectors.load_word2vec_format(EMBEDDING_FILE, binary=True)

# %%
# calculate: (king - man) + woman = ?

result = model.most_similar(positive=['woman', 'king'], negative=['man'], topn=5)
print(result)
